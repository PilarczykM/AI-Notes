# %% [markdown]
# # Renaming and Combining
# Data comes in from many sources. Help it all make sense together

# %% [markdown]
# ## Introduction
# Oftentimes data will come to us with column names, index names, or other naming conventions that we are not satisfied with.

# %%
import pandas as pd

reviews = pd.read_csv("data/winemag-data-130k-v2.csv", index_col=0)
pd.set_option('display.max_rows', 5)

# %% [markdown]
# ## Renaming
# The first function we'll introduce here is `rename()`, which lets you change index names and/or column names. For example, to change the points column in our dataset to score, we would do:

# %%
reviews.rename(columns={'points': 'score'})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  score  price           province  \
# 0                        Vulkà Bianco     87    NaN  Sicily & Sardinia
# 1                            Avidagos     87   15.0              Douro
# ...                               ...    ...    ...                ...
# 129969                            NaN     90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline     90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# 0          Etna      NaN  Kerin O’Keefe          @kerinokeefe
# 1           NaN      NaN     Roger Voss            @vossroger
# ...         ...      ...            ...                   ...
# 129969   Alsace      NaN     Roger Voss            @vossroger
# 129970   Alsace      NaN     Roger Voss            @vossroger
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...                                                   ...             ...
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                       winery
# 0                    Nicosia
# 1        Quinta dos Avidagos
# ...                      ...
# 129969  Domaine Marcel Deiss
# 129970      Domaine Schoffit
#
# [129971 rows x 13 columns]

# %% [markdown]
# `rename()` lets you rename index or column values by specifying a `index` or `column` keyword parameter, respectively. It supports a variety of input formats, but usually a Python dictionary is the most convenient. Here is an example using it to rename some elements of the index.

# %%
reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#               country                                        description  \
# firstEntry      Italy  Aromas include tropical fruit, broom, brimston...
# secondEntry  Portugal  This is ripe and fruity, a wine that is smooth...
# ...               ...                                                ...
# 129969         France  A dry style of Pinot Gris, this is crisp with ...
# 129970         France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# firstEntry                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# secondEntry                       Avidagos      87   15.0              Douro
# ...                                    ...     ...    ...                ...
# 129969                                 NaN      90   32.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#             region_1 region_2    taster_name taster_twitter_handle  \
# firstEntry      Etna      NaN  Kerin O’Keefe          @kerinokeefe
# secondEntry      NaN      NaN     Roger Voss            @vossroger
# ...              ...      ...            ...                   ...
# 129969        Alsace      NaN     Roger Voss            @vossroger
# 129970        Alsace      NaN     Roger Voss            @vossroger
#
#                                                          title  \
# firstEntry                   Nicosia 2013 Vulkà Bianco  (Etna)
# secondEntry      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# ...                                                        ...
# 129969           Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 129970       Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...
#
#                     variety                winery
# firstEntry      White Blend               Nicosia
# secondEntry  Portuguese Red   Quinta dos Avidagos
# ...                     ...                   ...
# 129969           Pinot Gris  Domaine Marcel Deiss
# 129970       Gewürztraminer      Domaine Schoffit
#
# [129971 rows x 13 columns]

# %% [markdown]
# You'll probably rename columns very often, but rename index values very rarely. For that, `set_index()` is usually more convenient.
#
# Both the row index and the column index can have their own name attribute. The complimentary `rename_axis()` method may be used to change these names.
#
# For example:

# %%
reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields   country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
# fields                    designation  points  price           province  \
# wines
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
# fields region_1 region_2    taster_name taster_twitter_handle  \
# wines
# 0          Etna      NaN  Kerin O’Keefe          @kerinokeefe
# 1           NaN      NaN     Roger Voss            @vossroger
# ...         ...      ...            ...                   ...
# 129969   Alsace      NaN     Roger Voss            @vossroger
# 129970   Alsace      NaN     Roger Voss            @vossroger
#
# fields                                              title         variety  \
# wines
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...                                                   ...             ...
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
# fields                winery
# wines
# 0                    Nicosia
# 1        Quinta dos Avidagos
# ...                      ...
# 129969  Domaine Marcel Deiss
# 129970      Domaine Schoffit
#
# [129971 rows x 13 columns]

# %% [markdown]
# ## Combining
# When performing operations on a dataset, we will sometimes need to combine different DataFrames and/or Series in non-trivial ways. Pandas has three core methods for doing this. In order of increasing complexity, these are `concat()`, `join()`, and `merge()`. Most of what `merge()` can do can also be done more simply with `join()`, so we will omit it and focus on the first two functions here.
#
# The simplest combining method is `concat()`. Given a list of elements, this function will smush those elements together along an axis.
#
# This is useful when we have data in different DataFrame or Series objects but having the same fields (columns). One example: the [YouTube Videos dataset](https://www.kaggle.com/datasnaek/youtube-new), which splits the data up based on country of origin (e.g. Canada and the UK, in this example). If we want to study multiple countries simultaneously, we can use `concat()` to smush them together:

# %%
canadian_youtube = pd.read_csv("data/CAvideos.csv")
british_youtube = pd.read_csv("data/GBvideos.csv")

pd.concat([canadian_youtube, british_youtube])
# Out:
#        Unnamed: 0.1 Unnamed: 0     video_id trending_date  \
# 0               0.0          0  Jw1Y-zhQURU      17.14.11
# 1               1.0          1  3s1rvMFUweQ      17.14.11
# ...             ...        ...          ...           ...
# 29400           NaN      29186  J-dv_DcDD_A      18.18.04
# 29401           NaN      29187  JwAnH6PLimo      18.18.04
#
#                                                    title        channel_title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster           John Lewis
# 1              Taylor Swift: …Ready for It? (Live) - SNL  Saturday Night Live
# ...                                                  ...                  ...
# 29400                     ZAYN - Let Me (Official Video)             ZaynVEVO
# 29401  Young Thug - Anybody (ft. Nicki Minaj) [Offici...           Young Thug
#
#        category_id              publish_time  \
# 0             26.0  2017-11-10T07:38:29.000Z
# 1             24.0  2017-11-12T06:24:44.000Z
# ...            ...                       ...
# 29400         10.0  2018-04-12T12:00:04.000Z
# 29401         24.0  2018-04-13T03:00:30.000Z
#
#                                                     tags       views  \
# 0      christmas|"john lewis christmas"|"john lewis"|...   7224515.0
# 1      SNL|"Saturday Night Live"|"SNL Season 43"|"Epi...   1053632.0
# ...                                                  ...         ...
# 29400            Let Me|"Pop"|"RCA Records Label"|"ZAYN"  22769424.0
# 29401  Young Thug|"Up"|"Now"|"Anybody"|"Nicki Minaj"|...   2379543.0
#
#            likes  dislikes  comment_count  \
# 0        55681.0   10247.0         9479.0
# 1        25561.0    2294.0         2757.0
# ...          ...       ...            ...
# 29400  1059309.0   24724.0        79913.0
# 29401    94978.0    1912.0         6408.0
#
#                                        thumbnail_link comments_disabled  \
# 0      https://i.ytimg.com/vi/Jw1Y-zhQURU/default.jpg             False
# 1      https://i.ytimg.com/vi/3s1rvMFUweQ/default.jpg             False
# ...                                               ...               ...
# 29400  https://i.ytimg.com/vi/J-dv_DcDD_A/default.jpg             False
# 29401  https://i.ytimg.com/vi/JwAnH6PLimo/default.jpg             False
#
#       ratings_disabled video_error_or_removed  \
# 0                False                  False
# 1                False                  False
# ...                ...                    ...
# 29400            False                  False
# 29401            False                  False
#
#                                              description
# 0      Click here to continue the story and make your...
# 1      Musical guest Taylor Swift performs …Ready for...
# ...                                                  ...
# 29400  ZAYN’s brand new song “Let Me” \nGet it on App...
# 29401  Young Thug - Anybody (ft. Nicki Minaj) \nHear ...
#
# [51454 rows x 18 columns]

# %% [markdown]
# The middlemost combiner in terms of complexity is `join()`. `join()` lets you combine different DataFrame objects which have an index in common. For example, to pull down videos that happened to be trending on the same day in both Canada and the UK, we could do the following:

# %%
left = canadian_youtube.set_index(['title', 'trending_date'])
right = british_youtube.set_index(['title', 'trending_date'])

left.join(right, lsuffix='_CAN', rsuffix='_UK')
# Out:
#                                                                   Unnamed: 0.1  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11                  0
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11                  1
# ...                                                                        ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03              22050
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03              22051
#
#                                                                  Unnamed: 0_CAN  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11                   0
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11                   1
# ...                                                                         ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03               21848
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03               21849
#
#                                                                  video_id_CAN  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11       Jw1Y-zhQURU
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11       3s1rvMFUweQ
# ...                                                                       ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03       GEsK9GudV2M
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03       kIHhVkkHV2k
#
#                                                                     channel_title_CAN  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11                John Lewis
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11       Saturday Night Live
# ...                                                                               ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03            TroyeSivanVEVO
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03          How To Cook That
#
#                                                                   category_id_CAN  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11                  26.0
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11                  24.0
# ...                                                                           ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03                  10.0
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03                  26.0
#
#                                                                           publish_time_CAN  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11       2017-11-10T07:38:29.000Z
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11       2017-11-12T06:24:44.000Z
# ...                                                                                    ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03       2018-02-23T05:00:01.000Z
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03       2018-02-23T08:30:11.000Z
#
#                                                                                                            tags_CAN  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11       christmas|"john lewis christmas"|"john lewis"|...
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11       SNL|"Saturday Night Live"|"SNL Season 43"|"Epi...
# ...                                                                                                             ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03       troye sivan|"my my my"|"acoustic"|"live"|"my m...
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03       double rainbow|"double rainbow unicorn apple p...
#
#                                                                   views_CAN  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11       7224515.0
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11       1053632.0
# ...                                                                     ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03       1407827.0
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03        345350.0
#
#                                                                   likes_CAN  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11         55681.0
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11         25561.0
# ...                                                                     ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03         90870.0
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03          7397.0
#
#                                                                   dislikes_CAN  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11            10247.0
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11             2294.0
# ...                                                                        ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03             1070.0
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03              398.0
#
#                                                                   ...  \
# title                                              trending_date  ...
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11       ...
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11       ...
# ...                                                               ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03       ...
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03       ...
#
#                                                                                                             tags_UK  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11       christmas|"john lewis christmas"|"john lewis"|...
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11       SNL|"Saturday Night Live"|"SNL Season 43"|"Epi...
# ...                                                                                                             ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03       troye sivan|"my my my"|"acoustic"|"live"|"my m...
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03       double rainbow|"double rainbow unicorn apple p...
#
#                                                                    views_UK  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11       7224515.0
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11       1053632.0
# ...                                                                     ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03       1407827.0
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03        345350.0
#
#                                                                  likes_UK  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11       55681.0
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11       25561.0
# ...                                                                   ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03       90870.0
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03        7397.0
#
#                                                                  dislikes_UK  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11          10247.0
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11           2294.0
# ...                                                                      ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03           1070.0
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03            398.0
#
#                                                                  comment_count_UK  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11                9479.0
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11                2757.0
# ...                                                                           ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03                3630.0
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03                 991.0
#
#                                                                                                thumbnail_link_UK  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11       https://i.ytimg.com/vi/Jw1Y-zhQURU/default.jpg
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11       https://i.ytimg.com/vi/3s1rvMFUweQ/default.jpg
# ...                                                                                                          ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03       https://i.ytimg.com/vi/GEsK9GudV2M/default.jpg
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03       https://i.ytimg.com/vi/kIHhVkkHV2k/default.jpg
#
#                                                                  comments_disabled_UK  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11                     False
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11                     False
# ...                                                                               ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03                     False
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03                     False
#
#                                                                  ratings_disabled_UK  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11                    False
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11                    False
# ...                                                                              ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03                    False
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03                    False
#
#                                                                  video_error_or_removed_UK  \
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11                          False
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11                          False
# ...                                                                                    ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03                          False
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03                          False
#
#                                                                                                      description_UK
# title                                              trending_date
# John Lewis Christmas Ad 2017 - #MozTheMonster      17.14.11       Click here to continue the story and make your...
# Taylor Swift: …Ready for It? (Live) - SNL          17.14.11       Musical guest Taylor Swift performs …Ready for...
# ...                                                                                                             ...
# Troye Sivan - My My My! (Acoustic)                 18.05.03       “My My My!” available now: https://TroyeSivan....
# Double Rainbow Unicorn Apple Pie | How To Cook ... 18.05.03       Watch more Rainbow Desserts: https://www.youtu...
#
# [65078 rows x 31 columns]

# %% [markdown]
# The `lsuffix` and `rsuffix` parameters are necessary here because the data has the same column names in both British and Canadian datasets. If this wasn't true (because, say, we'd renamed them beforehand) we wouldn't need them.
